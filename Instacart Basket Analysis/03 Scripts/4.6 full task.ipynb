# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/thomaskimber/Desktop/Instacart Basket Analysis'

# %%
df_ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_ords_prods.shape
# Out:
# (32434489, 10)

# %%
df_ords_prods.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  \
# 0   2539329        1             1                   2
# 1   2539329        1             1                   2
# 2   2539329        1             1                   2
# 3   2539329        1             1                   2
# 4   2539329        1             1                   2
#
#    hour_of_the_day_for_order  days_since_prior_order  product_id  \
# 0                          8                     NaN         196
# 1                          8                     NaN       14084
# 2                          8                     NaN       12427
# 3                          8                     NaN       26088
# 4                          8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# 2                  3          0   both
# 3                  4          0   both
# 4                  5          0   both

# %%
# importing chacked products csv
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods = df_prods.drop(columns=['Unnamed: 0'])

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_prods.shape
# Out:
# (49672, 5)

# %%
df_ords_prods = df_ords_prods.drop(columns=['_merge'])

# %%
df_ords_prods.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  \
# 0   2539329        1             1                   2
# 1   2539329        1             1                   2
# 2   2539329        1             1                   2
# 3   2539329        1             1                   2
# 4   2539329        1             1                   2
#
#    hour_of_the_day_for_order  days_since_prior_order  product_id  \
# 0                          8                     NaN         196
# 1                          8                     NaN       14084
# 2                          8                     NaN       12427
# 3                          8                     NaN       26088
# 4                          8                     NaN       26405
#
#    add_to_cart_order  reordered
# 0                  1          0
# 1                  2          0
# 2                  3          0
# 3                  4          0
# 4                  5          0

# %%
# creating a new df called df_ords_prods_merged using product Id as the merge 
df_ords_prods_merged = df_prods.merge(df_ords_prods, on='product_id', indicator=True)

# %%
df_ords_prods_merged.tail(20)
# Out:
#           product_id            product_name  aisle_id  department_id  prices  \
# 32404839       49688  Fresh Foaming Cleanser        73             11    13.5
# 32404840       49688  Fresh Foaming Cleanser        73             11    13.5
# 32404841       49688  Fresh Foaming Cleanser        73             11    13.5
# 32404842       49688  Fresh Foaming Cleanser        73             11    13.5
# 32404843       49688  Fresh Foaming Cleanser        73             11    13.5
# 32404844       49688  Fresh Foaming Cleanser        73             11    13.5
# 32404845       49688  Fresh Foaming Cleanser        73             11    13.5
# 32404846       49688  Fresh Foaming Cleanser        73             11    13.5
# 32404847       49688  Fresh Foaming Cleanser        73             11    13.5
# 32404848       49688  Fresh Foaming Cleanser        73             11    13.5
# 32404849       49688  Fresh Foaming Cleanser        73             11    13.5
# ...

# %%
df_ords_prods_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
